# %% [markdown]
# ## Identify hand-drawn digits prototype v2: EMNIST

# %% [markdown]
# ### Imports

# %%
import torch
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Hyperparameters and datasets

# %%
INPUT_SIZE: int = 28 * 28
CLASS_CNT: int = 62
TRAIN_BATCH_SZ: int = 128
TEST_BATCH_SZ: int = 1000
EPOCHS: int = 50
LEARN_RATE = 0.01

torch.manual_seed(0x10f2c)

transformation = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5), (0.5))]
)

training_set: datasets.EMNIST = datasets.EMNIST(
    root= "./data",
    train= True,
    download= True,
    transform= transformation,
    split= "balanced"
)

test_set: datasets.EMNIST = datasets.EMNIST(
    root= "./data",
    train= False,
    download= True,
    transform= transformation,
    split= "balanced"
)

train_load: DataLoader = DataLoader(
    dataset= training_set,
    batch_size= TRAIN_BATCH_SZ,
    shuffle= True,
    pin_memory= True,
    num_workers= 4
)

test_load: DataLoader = DataLoader(
    dataset= test_set,
    batch_size= TEST_BATCH_SZ,
    shuffle= False,
    pin_memory= True,
    num_workers= 4
)

device: str = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ### Demo Training Data

# %%
load_enumerate = enumerate(train_load)
idx, (demo_data, demo_target) = next(load_enumerate)

fig: plt.figure = plt.figure()

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.tight_layout()
    plt.imshow(demo_data[i][0].t(), cmap= "gray", interpolation= "none")
    plt.title(f"Actual: {demo_target[i]}")
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### Model Definition

# %%
class Digitv2Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(
            in_channels= 1,
            out_channels= 5,
            kernel_size= 3,
            padding= "same",
            padding_mode= "zeros",
        )
        self.pool1 = nn.MaxPool2d(
            kernel_size= 2,
            stride= 2,
        )
        self.conv2 = nn.Conv2d(
            in_channels= 5,
            out_channels= 10,
            kernel_size= 3,
            padding= "same",
            padding_mode= "zeros",
        )
        self.pool2 = nn.MaxPool2d(
            kernel_size= 2,
            stride= 2,
        )
        self.l1 = nn.Linear(int(10 * INPUT_SIZE / 16), 3 * CLASS_CNT)
        self.l2 = nn.Linear(3 * CLASS_CNT, CLASS_CNT)

    def forward(self, x: torch.Tensor):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool1(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool2(x)
        x = x.view(-1, int(10 * INPUT_SIZE / 16))
        x = self.l1(x)
        x = self.relu(x)
        x = self.l2(x)
        return x

model = Digitv2Network().to(device)
print(model)
# Out:
# Digitv2Network(
#   (relu): ReLU()
#   (conv1): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(5, 10, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (l1): Linear(in_features=490, out_features=186, bias=True)
#   (l2): Linear(in_features=186, out_features=62, bias=True)
# )

# %% [markdown]
# ### Training the model

# %%
criterion: nn.CrossEntropyLoss = nn.CrossEntropyLoss()
optimizer: torch.optim.SGD = torch.optim.SGD(model.parameters(), lr= LEARN_RATE)

n_steps = len(train_load)

for epoch in range(EPOCHS):
    for i, (img, label) in enumerate(train_load):
        img = img.to(device, non_blocking= True)
        label = label.to(device, non_blocking= True)
        # forward pass
        output = model(img)
        loss: torch.Tensor = criterion(output, label).to(device)

        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i + 1) % TRAIN_BATCH_SZ == 0:
            print(f"Epoch {epoch + 1}/{EPOCHS}, step {i + 1}/{n_steps}, loss = {loss.item():.4f}")
# Out:
# Epoch 1/50, step 128/882, loss = 4.1004
# Epoch 1/50, step 256/882, loss = 4.0435
# Epoch 1/50, step 384/882, loss = 3.8898
# Epoch 1/50, step 512/882, loss = 3.8156
# Epoch 1/50, step 640/882, loss = 3.7576
# Epoch 1/50, step 768/882, loss = 3.5378
# Epoch 2/50, step 128/882, loss = 2.0759
# Epoch 2/50, step 256/882, loss = 1.8786
# Epoch 2/50, step 384/882, loss = 1.4926
# Epoch 2/50, step 512/882, loss = 1.2821
# Epoch 2/50, step 640/882, loss = 1.4374
# Epoch 2/50, step 768/882, loss = 1.5930
# Epoch 3/50, step 128/882, loss = 0.9013
# Epoch 3/50, step 256/882, loss = 1.4133
# Epoch 3/50, step 384/882, loss = 1.0673
# Epoch 3/50, step 512/882, loss = 1.0528
# Epoch 3/50, step 640/882, loss = 1.1845
# Epoch 3/50, step 768/882, loss = 1.0041
# Epoch 4/50, step 128/882, loss = 0.9419
# Epoch 4/50, step 256/882, loss = 1.0206
# Epoch 4/50, step 384/882, loss = 0.9799
# Epoch 4/50, step 512/882, loss = 0.9997
# Epoch 4/50, step 640/882, loss = 0.6560
# Epoch 4/50, step 768/882, loss = 0.7859
# Epoch 5/50, step 128/882, loss = 0.9676
# Epoch 5/50, step 256/882, loss = 0.7353
# Epoch 5/50, step 384/882, loss = 0.8186
# Epoch 5/50, step 512/882, loss = 0.7637
# Epoch 5/50, step 640/882, loss = 0.8626
# Epoch 5/50, step 768/882, loss = 0.7656
# Epoch 6/50, step 128/882, loss = 0.7070
# Epoch 6/50, step 256/882, loss = 0.6486
# Epoch 6/50, step 384/882, loss = 0.7121
# Epoch 6/50, step 512/882, loss = 0.7835
# Epoch 6/50, step 640/882, loss = 0.5724
# Epoch 6/50, step 768/882, loss = 0.5343
# Epoch 7/50, step 128/882, loss = 0.4124
# Epoch 7/50, step 256/882, loss = 0.5517
# Epoch 7/50, step 384/882, loss = 0.6374
# Epoch 7/50, step 512/882, loss = 0.4481
# Epoch 7/50, step 640/882, loss = 0.7745
# Epoch 7/50, step 768/882, loss = 0.4440
# Epoch 8/50, step 128/882, loss = 0.4605
# Epoch 8/50, step 256/882, loss = 0.4435
# Epoch 8/50, step 384/882, loss = 0.6635
# Epoch 8/50, step 512/882, loss = 0.4805
# Epoch 8/50, step 640/882, loss = 0.5385
# Epoch 8/50, step 768/882, loss = 0.4544
# Epoch 9/50, step 128/882, loss = 0.5718
# Epoch 9/50, step 256/882, loss = 0.4578
# Epoch 9/50, step 384/882, loss = 0.5493
# Epoch 9/50, step 512/882, loss = 0.5414
# Epoch 9/50, step 640/882, loss = 0.4755
# Epoch 9/50, step 768/882, loss = 0.3110
# Epoch 10/50, step 128/882, loss = 0.6111
# Epoch 10/50, step 256/882, loss = 0.5480
# Epoch 10/50, step 384/882, loss = 0.5484
# Epoch 10/50, step 512/882, loss = 0.5253
# Epoch 10/50, step 640/882, loss = 0.5434
# Epoch 10/50, step 768/882, loss = 0.4173
# Epoch 11/50, step 128/882, loss = 0.5298
# Epoch 11/50, step 256/882, loss = 0.6320
# Epoch 11/50, step 384/882, loss = 0.4201
# Epoch 11/50, step 512/882, loss = 0.5487
# Epoch 11/50, step 640/882, loss = 0.4024
# Epoch 11/50, step 768/882, loss = 0.6881
# Epoch 12/50, step 128/882, loss = 0.3705
# Epoch 12/50, step 256/882, loss = 0.4887
# Epoch 12/50, step 384/882, loss = 0.3108
# Epoch 12/50, step 512/882, loss = 0.4338
# Epoch 12/50, step 640/882, loss = 0.5160
# Epoch 12/50, step 768/882, loss = 0.4062
# Epoch 13/50, step 128/882, loss = 0.4239
# Epoch 13/50, step 256/882, loss = 0.4703
# Epoch 13/50, step 384/882, loss = 0.4046
# Epoch 13/50, step 512/882, loss = 0.5051
# Epoch 13/50, step 640/882, loss = 0.3797
# Epoch 13/50, step 768/882, loss = 0.3992
# Epoch 14/50, step 128/882, loss = 0.4915
# Epoch 14/50, step 256/882, loss = 0.3919
# Epoch 14/50, step 384/882, loss = 0.4879
# Epoch 14/50, step 512/882, loss = 0.5470
# Epoch 14/50, step 640/882, loss = 0.6109
# Epoch 14/50, step 768/882, loss = 0.5415
# Epoch 15/50, step 128/882, loss = 0.4033
# Epoch 15/50, step 256/882, loss = 0.4911
# Epoch 15/50, step 384/882, loss = 0.4937
# Epoch 15/50, step 512/882, loss = 0.3822
# Epoch 15/50, step 640/882, loss = 0.4848
# Epoch 15/50, step 768/882, loss = 0.4084
# Epoch 16/50, step 128/882, loss = 0.3496
# Epoch 16/50, step 256/882, loss = 0.3043
# Epoch 16/50, step 384/882, loss = 0.4629
# Epoch 16/50, step 512/882, loss = 0.2650
# Epoch 16/50, step 640/882, loss = 0.5566
# Epoch 16/50, step 768/882, loss = 0.4636
# Epoch 17/50, step 128/882, loss = 0.3053
# Epoch 17/50, step 256/882, loss = 0.4473
# Epoch 17/50, step 384/882, loss = 0.4134
# Epoch 17/50, step 512/882, loss = 0.4634
# Epoch 17/50, step 640/882, loss = 0.4194
# Epoch 17/50, step 768/882, loss = 0.3778
# Epoch 18/50, step 128/882, loss = 0.3030
# Epoch 18/50, step 256/882, loss = 0.4339
# Epoch 18/50, step 384/882, loss = 0.3311
# Epoch 18/50, step 512/882, loss = 0.3415
# Epoch 18/50, step 640/882, loss = 0.2981
# Epoch 18/50, step 768/882, loss = 0.4173
# Epoch 19/50, step 128/882, loss = 0.3974
# Epoch 19/50, step 256/882, loss = 0.5534
# Epoch 19/50, step 384/882, loss = 0.2687
# Epoch 19/50, step 512/882, loss = 0.3206
# Epoch 19/50, step 640/882, loss = 0.2801
# Epoch 19/50, step 768/882, loss = 0.5068
# Epoch 20/50, step 128/882, loss = 0.2397
# Epoch 20/50, step 256/882, loss = 0.4725
# Epoch 20/50, step 384/882, loss = 0.2358
# Epoch 20/50, step 512/882, loss = 0.4882
# Epoch 20/50, step 640/882, loss = 0.3707
# Epoch 20/50, step 768/882, loss = 0.4899
# Epoch 21/50, step 128/882, loss = 0.3476
# Epoch 21/50, step 256/882, loss = 0.2911
# Epoch 21/50, step 384/882, loss = 0.3653
# Epoch 21/50, step 512/882, loss = 0.3892
# Epoch 21/50, step 640/882, loss = 0.3789
# Epoch 21/50, step 768/882, loss = 0.4168
# Epoch 22/50, step 128/882, loss = 0.3305
# Epoch 22/50, step 256/882, loss = 0.4614
# Epoch 22/50, step 384/882, loss = 0.2676
# Epoch 22/50, step 512/882, loss = 0.3431
# Epoch 22/50, step 640/882, loss = 0.3696
# Epoch 22/50, step 768/882, loss = 0.3775
# Epoch 23/50, step 128/882, loss = 0.4498
# Epoch 23/50, step 256/882, loss = 0.3439
# Epoch 23/50, step 384/882, loss = 0.3076
# Epoch 23/50, step 512/882, loss = 0.4284
# Epoch 23/50, step 640/882, loss = 0.3717
# Epoch 23/50, step 768/882, loss = 0.3681
# Epoch 24/50, step 128/882, loss = 0.2923
# Epoch 24/50, step 256/882, loss = 0.2987
# Epoch 24/50, step 384/882, loss = 0.4041
# Epoch 24/50, step 512/882, loss = 0.3762
# Epoch 24/50, step 640/882, loss = 0.2474
# Epoch 24/50, step 768/882, loss = 0.2869
# Epoch 25/50, step 128/882, loss = 0.3635
# Epoch 25/50, step 256/882, loss = 0.3083
# Epoch 25/50, step 384/882, loss = 0.3047
# Epoch 25/50, step 512/882, loss = 0.3752
# Epoch 25/50, step 640/882, loss = 0.3249
# Epoch 25/50, step 768/882, loss = 0.3108
# Epoch 26/50, step 128/882, loss = 0.3750
# Epoch 26/50, step 256/882, loss = 0.3051
# Epoch 26/50, step 384/882, loss = 0.3005
# Epoch 26/50, step 512/882, loss = 0.3456
# Epoch 26/50, step 640/882, loss = 0.3959
# Epoch 26/50, step 768/882, loss = 0.3106
# Epoch 27/50, step 128/882, loss = 0.3085
# Epoch 27/50, step 256/882, loss = 0.3574
# Epoch 27/50, step 384/882, loss = 0.4208
# Epoch 27/50, step 512/882, loss = 0.2851
# Epoch 27/50, step 640/882, loss = 0.2618
# Epoch 27/50, step 768/882, loss = 0.3076
# Epoch 28/50, step 128/882, loss = 0.4676
# Epoch 28/50, step 256/882, loss = 0.3327
# Epoch 28/50, step 384/882, loss = 0.3509
# Epoch 28/50, step 512/882, loss = 0.4709
# Epoch 28/50, step 640/882, loss = 0.2734
# Epoch 28/50, step 768/882, loss = 0.2533
# Epoch 29/50, step 128/882, loss = 0.2798
# Epoch 29/50, step 256/882, loss = 0.3609
# Epoch 29/50, step 384/882, loss = 0.3731
# Epoch 29/50, step 512/882, loss = 0.2258
# Epoch 29/50, step 640/882, loss = 0.2163
# Epoch 29/50, step 768/882, loss = 0.3836
# Epoch 30/50, step 128/882, loss = 0.3185
# Epoch 30/50, step 256/882, loss = 0.2734
# Epoch 30/50, step 384/882, loss = 0.3219
# Epoch 30/50, step 512/882, loss = 0.3314
# Epoch 30/50, step 640/882, loss = 0.2406
# Epoch 30/50, step 768/882, loss = 0.3879
# Epoch 31/50, step 128/882, loss = 0.3331
# Epoch 31/50, step 256/882, loss = 0.2958
# Epoch 31/50, step 384/882, loss = 0.2152
# Epoch 31/50, step 512/882, loss = 0.3039
# Epoch 31/50, step 640/882, loss = 0.3236
# Epoch 31/50, step 768/882, loss = 0.4021
# Epoch 32/50, step 128/882, loss = 0.4375
# Epoch 32/50, step 256/882, loss = 0.3399
# Epoch 32/50, step 384/882, loss = 0.2875
# Epoch 32/50, step 512/882, loss = 0.3367
# Epoch 32/50, step 640/882, loss = 0.5532
# Epoch 32/50, step 768/882, loss = 0.1931
# Epoch 33/50, step 128/882, loss = 0.3638
# Epoch 33/50, step 256/882, loss = 0.4481
# Epoch 33/50, step 384/882, loss = 0.2496
# Epoch 33/50, step 512/882, loss = 0.3938
# Epoch 33/50, step 640/882, loss = 0.3879
# Epoch 33/50, step 768/882, loss = 0.3331
# Epoch 34/50, step 128/882, loss = 0.2549
# Epoch 34/50, step 256/882, loss = 0.3734
# Epoch 34/50, step 384/882, loss = 0.3121
# Epoch 34/50, step 512/882, loss = 0.4237
# Epoch 34/50, step 640/882, loss = 0.2655
# Epoch 34/50, step 768/882, loss = 0.2394
# Epoch 35/50, step 128/882, loss = 0.3866
# Epoch 35/50, step 256/882, loss = 0.3805
# Epoch 35/50, step 384/882, loss = 0.3009
# Epoch 35/50, step 512/882, loss = 0.3470
# Epoch 35/50, step 640/882, loss = 0.3074
# Epoch 35/50, step 768/882, loss = 0.3513
# Epoch 36/50, step 128/882, loss = 0.2953
# Epoch 36/50, step 256/882, loss = 0.3692
# Epoch 36/50, step 384/882, loss = 0.3135
# Epoch 36/50, step 512/882, loss = 0.3506
# Epoch 36/50, step 640/882, loss = 0.2514
# Epoch 36/50, step 768/882, loss = 0.2897
# Epoch 37/50, step 128/882, loss = 0.2299
# Epoch 37/50, step 256/882, loss = 0.2794
# Epoch 37/50, step 384/882, loss = 0.3180
# Epoch 37/50, step 512/882, loss = 0.2389
# Epoch 37/50, step 640/882, loss = 0.3363
# Epoch 37/50, step 768/882, loss = 0.4296
# Epoch 38/50, step 128/882, loss = 0.3061
# Epoch 38/50, step 256/882, loss = 0.3566
# Epoch 38/50, step 384/882, loss = 0.2260
# Epoch 38/50, step 512/882, loss = 0.4181
# Epoch 38/50, step 640/882, loss = 0.3329
# Epoch 38/50, step 768/882, loss = 0.2858
# Epoch 39/50, step 128/882, loss = 0.3898
# Epoch 39/50, step 256/882, loss = 0.2586
# Epoch 39/50, step 384/882, loss = 0.2445
# Epoch 39/50, step 512/882, loss = 0.3479
# Epoch 39/50, step 640/882, loss = 0.3064
# Epoch 39/50, step 768/882, loss = 0.4099
# Epoch 40/50, step 128/882, loss = 0.2439
# Epoch 40/50, step 256/882, loss = 0.2238
# Epoch 40/50, step 384/882, loss = 0.2688
# Epoch 40/50, step 512/882, loss = 0.3481
# Epoch 40/50, step 640/882, loss = 0.2242
# Epoch 40/50, step 768/882, loss = 0.1858
# Epoch 41/50, step 128/882, loss = 0.2267
# Epoch 41/50, step 256/882, loss = 0.2817
# Epoch 41/50, step 384/882, loss = 0.2276
# Epoch 41/50, step 512/882, loss = 0.3166
# Epoch 41/50, step 640/882, loss = 0.2552
# Epoch 41/50, step 768/882, loss = 0.3159
# Epoch 42/50, step 128/882, loss = 0.3044
# Epoch 42/50, step 256/882, loss = 0.2990
# Epoch 42/50, step 384/882, loss = 0.1968
# Epoch 42/50, step 512/882, loss = 0.3046
# Epoch 42/50, step 640/882, loss = 0.3613
# Epoch 42/50, step 768/882, loss = 0.3310
# Epoch 43/50, step 128/882, loss = 0.2770
# Epoch 43/50, step 256/882, loss = 0.2399
# Epoch 43/50, step 384/882, loss = 0.3494
# Epoch 43/50, step 512/882, loss = 0.1990
# Epoch 43/50, step 640/882, loss = 0.1901
# Epoch 43/50, step 768/882, loss = 0.2423
# Epoch 44/50, step 128/882, loss = 0.2286
# Epoch 44/50, step 256/882, loss = 0.2446
# Epoch 44/50, step 384/882, loss = 0.2572
# Epoch 44/50, step 512/882, loss = 0.3158
# Epoch 44/50, step 640/882, loss = 0.2681
# Epoch 44/50, step 768/882, loss = 0.3168
# Epoch 45/50, step 128/882, loss = 0.1921
# Epoch 45/50, step 256/882, loss = 0.4869
# Epoch 45/50, step 384/882, loss = 0.2354
# Epoch 45/50, step 512/882, loss = 0.1981
# Epoch 45/50, step 640/882, loss = 0.2539
# Epoch 45/50, step 768/882, loss = 0.3437
# Epoch 46/50, step 128/882, loss = 0.2351
# Epoch 46/50, step 256/882, loss = 0.3641
# Epoch 46/50, step 384/882, loss = 0.3322
# Epoch 46/50, step 512/882, loss = 0.1710
# Epoch 46/50, step 640/882, loss = 0.2743
# Epoch 46/50, step 768/882, loss = 0.1741
# Epoch 47/50, step 128/882, loss = 0.2318
# Epoch 47/50, step 256/882, loss = 0.2090
# Epoch 47/50, step 384/882, loss = 0.3329
# Epoch 47/50, step 512/882, loss = 0.3564
# Epoch 47/50, step 640/882, loss = 0.3779
# Epoch 47/50, step 768/882, loss = 0.2212
# Epoch 48/50, step 128/882, loss = 0.3137
# Epoch 48/50, step 256/882, loss = 0.3099
# Epoch 48/50, step 384/882, loss = 0.4536
# Epoch 48/50, step 512/882, loss = 0.2841
# Epoch 48/50, step 640/882, loss = 0.2329
# Epoch 48/50, step 768/882, loss = 0.2056
# Epoch 49/50, step 128/882, loss = 0.1936
# Epoch 49/50, step 256/882, loss = 0.3622
# Epoch 49/50, step 384/882, loss = 0.2750
# Epoch 49/50, step 512/882, loss = 0.4240
# Epoch 49/50, step 640/882, loss = 0.4326
# Epoch 49/50, step 768/882, loss = 0.2256
# Epoch 50/50, step 128/882, loss = 0.2856
# Epoch 50/50, step 256/882, loss = 0.2928
# Epoch 50/50, step 384/882, loss = 0.2563
# Epoch 50/50, step 512/882, loss = 0.3426
# Epoch 50/50, step 640/882, loss = 0.2595
# Epoch 50/50, step 768/882, loss = 0.2306

# %% [markdown]
# ### Testing the model

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for img, labels in test_load:
        img = img.to(device, non_blocking= True)
        labels = labels.to(device, non_blocking= True)
        
        output = model(img)
        _, prediction = torch.max(output, 1)
        total += labels.size(0)
        correct += (prediction == labels).sum().item()

    acc = 100.0 * correct / total
    print(f"Accuracy: {acc}%")
# Out:
# Accuracy: 85.38297872340425%

# %% [markdown]
# ### Save

# %%
torch.save(model.state_dict(), "./digitsv2_emnist.pth")

# %% [markdown]
# ### Model Demo

# %%
with torch.no_grad():
    i, (img, label) = next(enumerate(test_load))
    img = img.to(device)
    label = label.to(device)
    idx = int(np.random.rand() * TEST_BATCH_SZ)
    output: torch.Tensor = model(img[idx])

    outlist = [i.item() for i in list(output[0])]
    print(f"Predicted: {outlist.index(max(outlist))}")
    print(f"Actual: {label[idx]}")
    plt.imshow(img[idx][0].cpu().t(), cmap= "gray", interpolation= "none")
# Out:
# Predicted: 12
# Actual: 12
